# %% [markdown]
# ## 1.3 Extra — Comparison & Logical Operators
#
# _Continue here after finishing the core 1.3 notebook._

# %% [markdown]
# ### Comparison Operators
#
# We use comparison operators to compare two values. The result is always `True` or `False`.
#
# | Operator | Meaning |
# |----------|----------------------------|
# | `==` | Equal |
# | `!=` | Not equal |
# | `>` | Greater than |
# | `<` | Less than |
# | `>=` | Greater than or equal to |
# | `<=` | Less than or equal to |

# %%
print(3 > 2)     # True
print(3 >= 2)    # True
print(3 < 2)     # False
print(2 < 3)     # True
print(3 == 2)    # False
print(3 != 2)    # True
print(len('mango') == len('avocado'))  # False
print(len('mango') < len('avocado'))   # True
print(len('milk') == len('meat'))      # True

# %% [markdown]
# #### Identity & Membership Operators
#
# - `is` / `is not` — check if two variables refer to the same object
# - `in` / `not in` — check membership in a sequence

# %%
print('1 is 1', 1 is 1)
print('1 is not 2', 1 is not 2)
print('A in Alex', 'A' in 'Alex')
print('B in Alex', 'B' in 'Alex')
print('coding' in 'coding for all')

# %% [markdown]
# ### Logical Operators
#
# Python uses `and`, `or`, and `not` for logical operations.
#
# | Operator | Description |
# |----------|-----------------------------------|
# | `and` | True if **both** are true |
# | `or` | True if **at least one** is true |
# | `not` | Inverts the boolean value |

# %%
print(3 > 2 and 4 > 3) # True
print(3 > 2 and 4 < 3) # False
print(3 > 2 or 4 < 3)  # True
print(3 < 2 or 4 < 3)  # False
print(not 3 > 2)        # False
print(not True)          # False
print(not False)         # True

# %% [markdown]
# ---
# Continue to [1.4_strings](../1.4_strings/1.4_strings.ipynb)
