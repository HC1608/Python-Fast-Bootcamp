# %% [markdown]
# _Module overview and learning roadmap. Open each submodule notebook in order._

# %% [markdown]
# ---
#
# ## Next
#
# Start with **1.1_intro — Introduction & Setup** in the [1.1_intro](./1.1_intro/) folder.
