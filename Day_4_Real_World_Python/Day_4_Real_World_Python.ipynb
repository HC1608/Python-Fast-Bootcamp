# %% [markdown]
# _Module overview and learning roadmap. Open each submodule notebook in order._

# %% [markdown]
# ---
#
# ## Next
#
# Start with **4.1_type_errors — Python Type Errors** in the [4.1_type_errors](./4.1_type_errors/) folder.
