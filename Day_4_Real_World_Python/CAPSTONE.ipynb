# %% [markdown]
# # Day 4 Capstone — Log File Analyzer
#
# **Time:** ~30 minutes. **Topics:** type errors, datetime, exceptions, regex, files.
#
# You are tasked with analyzing a web server log file. Each line in the log follows this pattern:
# `[2026-05-02 14:30:05] ERROR: Connection failed from 192.168.1.1`
#
# ## Tasks
#
# 1. **File & Regex**: Read a list of log lines. Extract the **timestamp** (as a string) and the **IP address** using `re.search` or `re.findall`.
# 2. **Datetime**: Convert the timestamp string into a Python `datetime` object.
# 3. **Exceptions**: Write a function `get_hour(log_line)` that extracts the hour (0-23) from the timestamp. It must use a `try/except` block to return `None` if the line is malformed or regex fails.
# 4. **Type Errors**: Ensure your logic handles missing data (None) without crashing. Use `if x is not None` checks.
#
# ## Data
#
# Use the `LOG_DATA` provided in the cell below.

# %%
import re
from datetime import datetime

LOG_DATA = [
    "[2026-05-01 08:20:00] INFO: User login from 10.0.0.5",
    "[2026-05-01 09:45:12] ERROR: Database timeout from 10.0.0.1",
    "MALFORMED LINE WITHOUT BRACKETS",
    "[2026-05-01 23:59:59] WARNING: High disk usage from 10.0.0.10",
]

def analyze_logs(logs):
    # Implement your logic here
    # Return a list of tuples: (datetime_obj, ip_string)
    pass

def get_hour(line):
    # Use try/except
    pass

# %% [markdown]
# ## Tests

# %%
# Test get_hour
assert get_hour(LOG_DATA[0]) == 8
assert get_hour(LOG_DATA[2]) is None

# Test analyze_logs
results = analyze_logs(LOG_DATA)
assert len(results) == 3
assert isinstance(results[0][0], datetime)
assert results[0][1] == "10.0.0.5"
assert results[2][1] == "10.0.0.10"

print("All Day 4 Capstone tests passed!")
