# %% [markdown]
# ## Submodule 4.1 — Type Errors

# %% [markdown]
# **Example: SyntaxError**
#
# ```python
# >>> print 'hello world'
#   File "<stdin>", line 1
#     print 'hello world'
#                       ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello world')?
# ```

# %% [markdown]
# **Fix**
#
# ```python
# >>> print('hello world')
# hello world
# ```

# %% [markdown]
# As you can see we made a syntax error because we forgot to enclose the string with parenthesis and Python already suggests the solution. Let us fix it.

# %% [markdown]
# The error was a _SyntaxError_. After the fix our code was executed without a hitch. Let see more error types.

# %% [markdown]
# ### NameError
#
# **Example 1: NameError**

# %% [markdown]
# As you can see from the message above, name age is not defined. Yes, it is true that we did not define an age variable but we were trying to print it out as if we had had declared it. Now, lets fix this by declaring it and assigning with a value.

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> print(age)
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# NameError: name 'age' is not defined
# >>> age = 25
# >>> print(age)
# 25
# ```

# %% [markdown]
# The type of error was a _NameError_. We debugged the error by defining the variable name.

# %% [markdown]
# ### IndexError
#
# **Example 1: IndexError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> numbers = [1, 2, 3, 4, 5]
# >>> numbers[5]
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# IndexError: list index out of range
# ```

# %% [markdown]
# In the example above, Python raised an _IndexError_, because the list has only indexes from 0 to 4 , so it was out of range.

# %% [markdown]
# ### ModuleNotFoundError
#
# **Example 1: ModuleNotFoundError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> import maths
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ModuleNotFoundError: No module named 'maths'
# ```

# %% [markdown]
# In the example above, I added an extra s to math deliberately and _ModuleNotFoundError_ was raised. Lets fix it by removing the extra s from math.

# %% [markdown]
# **Fix**
#
# ```python
# >>> import math
# ```

# %% [markdown]
# We fixed it, so let's use some of the functions from the math module.

# %% [markdown]
# ### AttributeError
#
# **Example 1: AttributeError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> import math
# >>> math.PI
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# AttributeError: module 'math' has no attribute 'PI'
# ```

# %% [markdown]
# As you can see, I made a mistake again! Instead of pi, I tried to call a PI constant from maths module. It raised an attribute error, it means, that the attribute does not exist in the module. Lets fix it by changing from PI to pi.

# %% [markdown]
# **Fix**
#
# ```python
# >>> math.pi
# 3.141592653589793
# ```

# %% [markdown]
# Now, when we call pi from the math module we got the result.

# %% [markdown]
# ### KeyError
#
# **Example 1: KeyError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> users = {'name':'Asab', 'age':250, 'country':'Finland'}
# >>> users['name']
# 'Asab'
# >>> users['county']
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# KeyError: 'county'
# ```

# %% [markdown]
# As you can see, there was a typo in the key used to get the dictionary value. so, this is a key error and the fix is quite straight forward. Let's do this!

# %% [markdown]
# **Fix**
#
# ```python
# >>> users['country']
# 'Finland'
# ```

# %% [markdown]
# We debugged the error, our code ran and we got the value.

# %% [markdown]
# ### TypeError
#
# **Example 1: TypeError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> 4 + '3'
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# ```

# %% [markdown]
# In the example above, a TypeError is raised because we cannot add a number to a string. First solution would be to convert the string to int or float. Another solution would be converting the number to a string (the result then would be '43'). Let us follow the first fix.

# %% [markdown]
# **Fix**
#
# ```python
# >>> 4 + int('3')
# 7
# >>> 4 + float('3')
# 7.0
# ```

# %% [markdown]
# Error removed and we got the result we expected.

# %% [markdown]
# ### ImportError
#
# **Example 1: TypeError**

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> from math import power
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ImportError: cannot import name 'power' from 'math'
# ```

# %% [markdown]
# There is no function called power in the math module, it goes with a different name: _pow_. Let's correct it:

# %% [markdown]
# **Fix**
#
# ```python
# >>> from math import pow
# >>> pow(2, 3)
# 8.0
# ```

# %% [markdown]
# ### ValueError

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> int('12a')
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ValueError: invalid literal for int() with base 10: '12a'
# ```

# %% [markdown]
# In this case we cannot change the given string to a number, because of the 'a' letter in it.

# %% [markdown]
# ### ZeroDivisionError

# %% [markdown]
# **REPL trace**
#
# ```python
# >>> 1 / 0
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ZeroDivisionError: division by zero
# ```

# %% [markdown]
# ## Challenges
#
# 1. **Diagnose three bugs.** Each of the following raises an error. Identify the error type, explain why, and fix it minimally: `print('age:' + 30)`, `nums = [1, 2, 3]; nums.add(4)`, `d = {'a': 1}; d.a`.
# 2. **Defensive coercion.** Write `to_int(value, default=0)` that returns `int(value)` if possible (handles strings like `"42"` and floats like `3.7`), and `default` otherwise — without ever raising.
# 3. **Custom error classes.** Create `InvalidEmailError` (inherits `ValueError`) and `EmailTooLongError` (inherits `InvalidEmailError`). Write `validate_email(s)` that raises the most specific applicable error. Show that catching `ValueError` catches both.

# %% [markdown]
# ---
#
# Continue to **[4.2 — Date & Time](../4.2_date_time/4.2_date_time.ipynb)**.
