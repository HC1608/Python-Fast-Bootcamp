# %% [markdown]
# ## Submodule 2.4 — Conditionals

# %% [markdown]
# **Syntax**
#
# ```python
# if condition:
#     # this part of code runs for truthy conditions
# ```

# %% [markdown]
# **Example: 1**

# %%
a = 3
if a > 0:
    print('A is a positive number')
# A is a positive number

# %% [markdown]
# As you can see in the example above, 3 is greater than 0. The condition was true and the block code was executed. However, if the condition is false, we do not see the result. In order to see the result of the falsy condition, we should have another block, which is going to be _else_.

# %% [markdown]
# ### If Else
#
# If condition is true the first block will be executed, if not the else condition will run.

# %% [markdown]
# **Syntax**
#
# ```python
# if condition:
#     # runs for truthy conditions
# else:
#     # runs for false conditions
# ```

# %% [markdown]
# **Example:**

# %%
a = 3
if a < 0:
    print('A is a negative number')
else:
    print('A is a positive number')

# %% [markdown]
# The condition above proves false, therefore the else block was executed. How about if our condition is more than two? We could use _elif_.

# %% [markdown]
# ### If Elif Else
#
# In our daily life, we make decisions on daily basis. We make decisions not by checking one or two conditions but multiple conditions. As similar to life, programming is also full of conditions. We use _elif_ when we have multiple conditions.

# %% [markdown]
# **Syntax**
#
# ```python
# if condition:
#     # code
# elif condition:
#     # code
# else:
#     # code
# ```

# %% [markdown]
# **Example:**

# %%
a = 0
if a > 0:
    print('A is a positive number')
elif a < 0:
    print('A is a negative number')
else:
    print('A is zero')

# %% [markdown]
# ### Short Hand

# %% [markdown]
# **Syntax**
#
# ```python
# value_if_true if condition else value_if_false
# ```

# %% [markdown]
# **Example:**

# %%
a = 3
print('A is positive') if a > 0 else print('A is negative') # first condition met, 'A is positive' will be printed

# %% [markdown]
# ### Nested Conditions
#
# Conditions can be nested

# %% [markdown]
# **Syntax**
#
# ```python
# if condition:
#     # code
#     if condition:
#         # code
# ```

# %% [markdown]
# **Example:**

# %%
a = 0
if a > 0:
    if a % 2 == 0:
        print('A is a positive and even integer')
    else:
        print('A is a positive number')
elif a == 0:
    print('A is zero')
else:
    print('A is a negative number')

# %% [markdown]
# We can avoid writing nested condition by using logical operator _and_.

# %% [markdown]
# ### If Condition and Logical Operators

# %% [markdown]
# **Syntax**
#
# ```python
# if condition and condition:
#     # code
# ```

# %% [markdown]
# **Example:**

# %%
a = 0
if a > 0 and a % 2 == 0:
        print('A is an even and positive integer')
elif a > 0 and a % 2 !=  0:
     print('A is a positive integer')
elif a == 0:
    print('A is zero')
else:
    print('A is negative')

# %% [markdown]
# ### If and Or Logical Operators

# %% [markdown]
# **Syntax**
#
# ```python
# if condition or condition:
#     # code
# ```

# %% [markdown]
# **Example:**

# %%
user = 'James'
access_level = 3
if user == 'admin' or access_level >= 4:
        print('Access granted!')
else:
    print('Access denied!')

# %% [markdown]
# ## Challenges
#
# 1. **Triangle classifier.** Read three side lengths. First validate they form a valid triangle (positive, and triangle inequality). Then classify as equilateral, isosceles, or scalene, *and* as acute, right, or obtuse — all using one well-structured `if/elif/else` chain.
# 2. **FizzBuzz, no ifs.** Print FizzBuzz for 1..30 *without using any* `if`, `elif`, `else`, or ternary expression. (Hint: dictionaries and string operations.)
# 3. **Date validity.** Given three integers `y, m, d`, return `True` if they form a valid Gregorian date — handling month lengths and leap years correctly. Do not import `datetime`.

# %% [markdown]
# ---
#
# Continue to the **[Day 2 Capstone](../CAPSTONE.ipynb)**.
