# %% [markdown]
# _Module overview and learning roadmap. Open each submodule notebook in order._

# %% [markdown]
# ---
#
# ## Next
#
# Start with **2.1_tuples — Tuples** in the [2.1_tuples](./2.1_tuples/) folder.
