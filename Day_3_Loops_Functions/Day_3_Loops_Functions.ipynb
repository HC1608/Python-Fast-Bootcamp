# %% [markdown]
# _Module overview and learning roadmap. Open each submodule notebook in order._

# %% [markdown]
# ---
#
# ## Next
#
# Start with **3.1_loops — Loops** in the [3.1_loops](./3.1_loops/) folder.
