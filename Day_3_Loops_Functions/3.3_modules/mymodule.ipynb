# %% [markdown]
# ## Submodule 3.3 — Modules
#
# _Work through each section in order. Run every code cell. Try the exercises at the end before moving on._

# %%
def generate_full_name(firstname, lastname):
      space = ' '
      fullname = firstname + space + lastname
      return fullname

def sum_two_nums (num1, num2):
    return num1 + num2
gravity = 9.81
person = {
    "firstname": "Asabeneh",
    "age": 250,
    "country": "Finland",
    "city":'Helsinki'
}

# %% [markdown]
# ## Challenges
#
# 1. **Roll your own module.** Create a new file `geo.py` next to this notebook exposing `distance(p1, p2)`, `midpoint(p1, p2)`, and `triangle_area(p1, p2, p3)`. Import it from this notebook and exercise every function. Add an `if __name__ == '__main__':` self-test block.
# 2. **Standard-library tour.** Use `math`, `random`, `statistics`, and `itertools` to: generate 10000 random samples from a normal distribution (mean=50, stdev=10), bucket them into 5-unit bins with `itertools.groupby`, and print a text histogram.
# 3. **dir + help.** Pick any object (e.g., a list). Use `dir` and `help` programmatically to print the names and one-line summaries of all *public* methods (those not starting with `_`).

# %% [markdown]
# ---
#
# ## Next
#
# Continue with **3.4_list_comprehension — List Comprehension**: [../3.4_list_comprehension/3.4_list_comprehension.ipynb](../3.4_list_comprehension/3.4_list_comprehension.ipynb)
