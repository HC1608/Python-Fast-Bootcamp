# %% [markdown]
# # Day 5 Capstone — Library Management System
#
# **Time:** ~45 minutes. **Topics:** classes, inheritance, polymorphism, encapsulation, abstraction.
#
# Build a small **Library Management System** using OOP principles.
#
# ## Requirements
#
# ### 1. Abstract Base Class — `LibraryItem` (Abstraction)
# - Abstract methods: `checkout()`, `return_item()`, `display_info()`
# - Concrete attribute: `title`, `item_id`, `is_checked_out` (boolean)
#
# ### 2. Classes — `Book` and `Magazine` (Inheritance)
# - `Book(title, item_id, author, pages)` — inherits from `LibraryItem`
# - `Magazine(title, item_id, issue_number)` — inherits from `LibraryItem`
# - Both must implement all abstract methods
#
# ### 3. Encapsulation
# - `is_checked_out` should be a private attribute with a read-only property
# - `checkout()` should fail if already checked out
# - `return_item()` should fail if not checked out
#
# ### 4. Polymorphism
# - Write a function `process_items(items)` that loops through a list of `LibraryItem` objects and calls `display_info()` on each
#
# ### 5. Library Class
# - `Library` stores a list of items
# - Methods: `add_item(item)`, `find_item(item_id)`, `list_available()`, `list_checked_out()`

# %%
from abc import ABC, abstractmethod

# Step 1: Define the abstract base class LibraryItem

# %%
# Step 2: Implement Book and Magazine classes

# %%
# Step 3: Implement the Library class

# %%
# Step 4: Write the process_items function

# %%
# Step 5: Test everything

# Create library
# lib = Library()

# Add items
# lib.add_item(Book('Clean Code', 'B001', 'Robert C. Martin', 464))
# lib.add_item(Book('Python Crash Course', 'B002', 'Eric Matthes', 544))
# lib.add_item(Magazine('National Geographic', 'M001', 'May 2026'))

# Checkout and return
# book = lib.find_item('B001')
# print(book.checkout())
# print(book.checkout())  # should fail

# List available and checked out
# lib.list_available()
# lib.list_checked_out()

# Polymorphism
# process_items([lib.find_item('B001'), lib.find_item('M001')])
