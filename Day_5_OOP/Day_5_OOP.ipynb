# %% [markdown]
# # Day 5 — Object-Oriented Programming (OOP)
#
# _Module overview and learning roadmap. Open each submodule notebook in order._
#
# ## Submodules
#
# | # | Topic | Folder |
# |---|---|---|
# | 5.1 | Classes and Objects | [5.1_classes_and_objects](./5.1_classes_and_objects/) |
# | 5.2 | Inheritance | [5.2_inheritance](./5.2_inheritance/) |
# | 5.3 | Polymorphism | [5.3_polymorphism](./5.3_polymorphism/) |
# | 5.4 | Encapsulation | [5.4_encapsulation](./5.4_encapsulation/) |
# | 5.5 | Abstraction | [5.5_abstraction](./5.5_abstraction/) |

# %% [markdown]
# ---
#
# ## Next
#
# Start with **5.1_classes_and_objects — Classes and Objects** in the [5.1_classes_and_objects](./5.1_classes_and_objects/) folder.
