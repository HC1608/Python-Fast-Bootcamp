# %% [markdown]
# ## Submodule 5.3 — Polymorphism
#
# **Polymorphism** means "many forms". It allows objects of different classes to be treated through the same interface. The same method name can behave differently depending on the object that calls it.

# %% [markdown]
# ### Polymorphism with Methods
#
# Different classes can define the same method name, and Python picks the right one at runtime.

# %%
class Dog:
    def speak(self):
        return 'Woof!'

class Cat:
    def speak(self):
        return 'Meow!'

class Duck:
    def speak(self):
        return 'Quack!'

# Same method name, different behavior
animals = [Dog(), Cat(), Duck()]
for animal in animals:
    print(animal.speak())

# %% [markdown]
# ### Polymorphism with Inheritance
#
# Child classes override a parent method, and we call them through a common interface.

# %%
class Shape:
    def area(self):
        return 0

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        import math
        return math.pi * self.radius ** 2

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

shapes = [Rectangle(4, 5), Circle(7), Triangle(6, 3)]
for shape in shapes:
    print(f'{shape.__class__.__name__}: area = {shape.area():.2f}')

# %% [markdown]
# ### Polymorphism with Functions
#
# A function can accept any object that has the expected method — this is called **duck typing**: _"If it walks like a duck and quacks like a duck, it's a duck."_

# %%
def print_area(shape):
    """Works with any object that has an area() method."""
    print(f'Area: {shape.area():.2f}')

print_area(Rectangle(10, 5))
print_area(Circle(3))
print_area(Triangle(8, 4))

# %% [markdown]
# ### Built-in Polymorphism
#
# Python's built-in functions like `len()`, `+`, and `str()` are polymorphic — they work differently depending on the type.

# %%
# len() works on strings, lists, dicts
print(len('hello'))       # 5
print(len([1, 2, 3]))     # 3
print(len({'a': 1}))      # 1

# + works differently for numbers vs strings
print(3 + 4)              # 7
print('hello' + ' world') # hello world

# %% [markdown]
# ### Operator Overloading (Dunder Methods)
#
# You can make your classes work with Python operators by defining special **dunder** (double underscore) methods.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f'Vector({self.x}, {self.y})'

    def __len__(self):
        return int((self.x ** 2 + self.y ** 2) ** 0.5)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

v1 = Vector(3, 4)
v2 = Vector(1, 2)
v3 = v1 + v2
print(v3)          # Vector(4, 6)
print(len(v1))     # 5
print(v1 == v2)    # False

# %% [markdown]
# ### Common Dunder Methods
#
# | Method | Operator/Function |
# |---|---|
# | `__add__` | `+` |
# | `__sub__` | `-` |
# | `__mul__` | `*` |
# | `__eq__` | `==` |
# | `__lt__` | `<` |
# | `__len__` | `len()` |
# | `__str__` | `str()` / `print()` |
# | `__repr__` | `repr()` |

# %% [markdown]
# ### Exercises
#
# 1. Create classes `PDF`, `Word`, and `Excel` each with a method `show()`. Write a function `display_all(docs)` that calls `show()` on each.
# 2. Create a `Money` class with `amount` and `currency`. Implement `__add__` so two Money objects of the same currency can be added.
# 3. Create a `Temperature` class that stores Celsius. Implement `__gt__`, `__lt__`, and `__eq__` to compare temperatures.

# %%
# Exercise 1

# %%
# Exercise 2

# %%
# Exercise 3
